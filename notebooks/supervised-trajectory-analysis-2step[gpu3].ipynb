# %%
# %run supervised_functions.ipynb
# Out:
# Calculating probability for start mol sampling
# 100%|██████████████████████████████████████████████████████████| 69304/69304 [01:30<00:00, 763.58it/s]

# %%
device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Action dataset

# %%
action_dataset = pd.read_csv("datasets/my_uspto/action_dataset-filtered.csv", index_col=0)
action_dataset = action_dataset.loc[action_dataset["action_tested"] & action_dataset["action_works"]]
action_dataset = action_dataset[["rsub", "rcen", "rsig", "rsig_cs_indices", "psub", "pcen", "psig", "psig_cs_indices"]]
print(action_dataset.shape)

action_rsigs = data.Molecule.pack(list(map(molecule_from_smile, action_dataset["rsig"])))
action_psigs = data.Molecule.pack(list(map(molecule_from_smile, action_dataset["psig"])))
# Out:
# (89384, 8)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Li`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Ge`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `K`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Na`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Ti`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Pb`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Al`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Ga`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Ru`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Ta`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `As`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Cr`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Cd`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Pt`
#   warnings.warn("Unknown value `%s`" % x)

# %% [markdown]
# # Get top k predictions

# %%
import time
def get_topk_predictions(model, source_list, target_list, topk=10):
    # Convert to mols
    if isinstance(source_list, pd.Series):
        source_list = source_list.tolist()
    if isinstance(target_list, pd.Series):
        target_list = target_list.tolist()
    tt = time.time()
    sources = data.Molecule.pack(list(map(molecule_from_smile, source_list)))
    targets = data.Molecule.pack(list(map(molecule_from_smile, target_list)))
    print(f"Took {time.time() - tt}s to pack molecules.")

    # Predictions
    batch_size = 1024
#     pred = model(sources, targets, None, None, "actor").detach()
    pred = torch.concatenate([model(sources[i:min(i+batch_size, sources.batch_size)].to(device), 
                                 targets[i:min(i+batch_size, sources.batch_size)].to(device), None, None, "actor").detach() for i in range(0, sources.batch_size, batch_size)], axis=0)

    action_embeddings = get_action_dataset_embeddings(model.GIN)

    # Get applicable actions for source(s)
    applicable_action_indices_list = []
    
    with Pool(30) as p:
        for idxes in tqdm.tqdm(p.imap(functools.partial(get_emb_indices_and_correct_idx, no_correct_idx=True), 
                                      [{"reactant": source_list[i]} for i in range(pred.shape[0])], chunksize=10),
                              total=pred.shape[0]):
            applicable_action_indices_list.append(idxes)

    # Sort by critic's Q
    dict_of_list_of_indices = {}
    
    for i in tqdm.tqdm(range(pred.shape[0])):
        pred_for_i = pred[i]
        adi = applicable_action_indices_list[i]
        if len(adi) == 0:
            dict_of_list_of_indices[i] = np.array([])
            continue

        # Get top 50 for actor
        dist = torch.linalg.norm(action_embeddings[adi] - pred[i], axis=1)
        dict_of_list_of_indices[i] = adi[torch.argsort(dist)[:50].cpu().numpy().astype(np.int64)]

    # Sort with critic's Q
    i_sorted = list(range(pred.shape[0]))
    action_indices = np.concatenate([dict_of_list_of_indices[i] for i in i_sorted])
    state_indices = np.concatenate([np.full_like(dict_of_list_of_indices[i], i) for i in i_sorted])
    critic_qs = []
    for i in tqdm.tqdm(range(0, action_indices.shape[0], batch_size)):
        batch_reactants = sources[state_indices[i:i+batch_size]]
        batch_products = targets[state_indices[i:i+batch_size]]
        batch_rsigs = action_rsigs[action_indices[i:i+batch_size]]
        batch_psigs = action_psigs[action_indices[i:i+batch_size]]
        critic_qs.append(ac(batch_reactants.to(device), batch_products.to(device), batch_rsigs.to(device), batch_psigs.to(device), "critic").detach().cpu().numpy())

    critic_qs = np.concatenate(critic_qs)

    # Get action predictions
    action_pred_indices = []
    start = 0
    for i in tqdm.tqdm(i_sorted):
        end = start + dict_of_list_of_indices[i].shape[0]
        i_critic_qs = critic_qs[start:end]

        action_pred_indices.append(dict_of_list_of_indices[i][i_critic_qs.reshape(-1).argsort()[::-1]][:topk])
        start = end

    return action_pred_indices
    
# %time pred = get_topk_predictions(ac, source_list[:100], target_list[target_list_idx][:100])
# print(len(pred))

# %%
def _generate_train_data(smile, steps):
    mol = Chem.MolFromSmiles(smile)

    df = pd.DataFrame(columns=['reactant', 'rsub', 'rcen', 'rsig', 'rsig_cs_indices', 'psub', 'pcen', 'psig', 'psig_cs_indices', 'product', 'step'])
    index = []
    
    # Get sequences
    try:
        for i in range(steps):
            actions = get_applicable_actions(mol)
            if actions.shape[0] == 0:
                break

            # Apply a random action
            rand_idx = np.random.randint(0, actions.shape[0])
            product = apply_action(mol, *actions.iloc[rand_idx])

            # Add it to df
            df.loc[df.shape[0], :] = [Chem.MolToSmiles(mol)] + actions.iloc[rand_idx].tolist() + [Chem.MolToSmiles(product), i]
            index.append(actions.iloc[rand_idx].name)

            # Next reactant = product
            mol = product
    except Exception as e:
        return pd.DataFrame(columns=['reactant', 'rsub', 'rcen', 'rsig', 'rsig_cs_indices', 'psub', 'pcen', 'psig', 'psig_cs_indices', 'product'])
    
    # Fix index
    df.index = index
    
    # Fix target
    df["product"] = Chem.MolToSmiles(product)

    # Fix step
    df['step'] = df.shape[0] - df['step']
    
    return df

def generate_train_data(N, steps, multiprocess=True):
    # Generate dataset
    df_list = []
    final_shape = 0
    smiles_per_random_sample = 300
    pool_chunk_size = 10

    # Create dataset for multi-step pred
    print("Creating dataset...")
    if multiprocess:
        with Pool(30) as p, tqdm.tqdm(total=N) as pbar:
            while final_shape < N:
                smiles = np.random.choice(start_mols, size=(smiles_per_random_sample,), p=categorical_probs_for_sampling_start_mols)

                for new_df in p.imap_unordered(functools.partial(_generate_train_data, steps=steps), smiles, chunksize=10):
                    df_list.append(new_df)
                    final_shape += new_df.shape[0]

                pbar.update(final_shape - pbar.n)
    else:
        raise Exception("Single process not implemented... :'(")

    main_df = pd.concat(df_list)
    return main_df

# %%
def apply_actions_on_reactant(args):
    reactant, action_dataset_idx = args
    listy = []
    for idx in action_dataset_idx:
        try:
            listy.append(Chem.MolToSmiles(apply_action(Chem.MolFromSmiles(reactant), *action_dataset.iloc[idx])))
        except Exception as e:
            pass
    return listy

# %% [markdown]
# ### Generate data

# %%
# Get test data
test_data_df = generate_train_data(N=2000, steps=2) # we'll get N/step trajectory samples from this
test_data_df.shape
# Out:
# Creating dataset...
# 2368it [00:06, 367.82it/s]
# (2368, 11)

# %%
temp_df = test_data_df[test_data_df['step'] == 2]
source_list, target_list = temp_df["reactant"].values, temp_df["product"].values
del temp_df
source_list.shape, target_list.shape
# Out:
# ((1168,), (1168,))

# %% [markdown]
# ### Load model

# %%
# Load model
import glob
# file_string = f"models/supervised/actor-critic/*{actor_loss}*steps={steps}*/model.pth"
file_string = f"models/supervised/offlineRL/emb_model_update=1||steps=2||topk=10/model.pth"
ac = torch.load(glob.glob(file_string)[0]).to(device)

# %% [markdown]
# ### Predictions (trajectories)

# %%
target_list_idx = np.arange(target_list.shape[0])

# initialize objects
trajectory_dict = {} # Keeps track of trajectory in dict format (need hash keeys for quick access)
for i in range(len(source_list)):
    trajectory_dict[str(i)] = source_list[i]
source_keys = list(map(str, list(range(len(source_list))))) # Map for index to keys of previous step in trajectory

# RUN -----------------------
for i_step in range(1, 4): 
    print("Running prediction for step", i_step)
    # Get action predictions
    # %time pred = get_topk_predictions(ac, source_list, target_list[target_list_idx])

    # get products
    temp_source_keys = []
    temp_source_list = []
    with Pool(30) as p:
        print("Applying actions for step", i_step)
        for i, product_list in tqdm.tqdm(enumerate(p.imap(apply_actions_on_reactant, zip(source_list, pred), chunksize=10)), total=len(pred)):
            for _i, product in enumerate(product_list):
                key = f"{source_keys[i]}_{_i}"
                trajectory_dict[key] = product
                temp_source_keys.append(key)
                temp_source_list.append(product)
                
    # update source list and source_keys for next step
    source_list = temp_source_list
    source_keys = temp_source_keys
    target_list_idx = list(map(lambda x: int(x.split("_")[0]), source_keys))
# Out:
# Running prediction for step 1
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Li`
#   warnings.warn("Unknown value `%s`" % x)
# Took 5.554426670074463s to pack molecules.
# 100%|█████████████████████████████████████████████████████████████████| 44/44 [00:04<00:00,  9.76it/s]
# 100%|████████████████████████████████████████████████████████████| 1928/1928 [00:02<00:00, 646.81it/s]
# 100%|███████████████████████████████████████████████████████████| 1928/1928 [00:00<00:00, 4188.57it/s]
# 100%|█████████████████████████████████████████████████████████████████| 94/94 [00:13<00:00,  7.15it/s]
# 100%|█████████████████████████████████████████████████████████| 1928/1928 [00:00<00:00, 120059.66it/s]
# CPU times: user 5min 49s, sys: 27.8 s, total: 6min 17s
# Wall time: 34.2 s
# Applying actions for step 1
# 100%|████████████████████████████████████████████████████████████| 1928/1928 [00:04<00:00, 471.45it/s]
# Running prediction for step 2
# Took 64.96120142936707s to pack molecules.
# 100%|█████████████████████████████████████████████████████████████████| 44/44 [00:04<00:00,  9.35it/s]
# 100%|██████████████████████████████████████████████████████████| 19256/19256 [00:41<00:00, 463.49it/s]
# 100%|█████████████████████████████████████████████████████████| 19256/19256 [00:04<00:00, 4784.36it/s]
# 100%|███████████████████████████████████████████████████████████████| 770/770 [01:53<00:00,  6.80it/s]
# 100%|███████████████████████████████████████████████████████| 19256/19256 [00:00<00:00, 129477.78it/s]
# CPU times: user 38min 55s, sys: 2min 26s, total: 41min 22s
# Wall time: 3min 57s
# Applying actions for step 2
# 100%|██████████████████████████████████████████████████████████| 19256/19256 [00:51<00:00, 375.90it/s]
# Running prediction for step 3
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Al`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `As`
#   warnings.warn("Unknown value `%s`" % x)
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/torchdrug-0.2.0-py3.7.egg/torchdrug/data/feature.py:42: UserWarning: Unknown value `Ga`
#   warnings.warn("Unknown value `%s`" % x)
# Took 651.6760439872742s to pack molecules.
# 100%|█████████████████████████████████████████████████████████████████| 44/44 [00:04<00:00,  9.90it/s]
# 100%|████████████████████████████████████████████████████████| 179538/179538 [07:19<00:00, 408.24it/s]
# 100%|███████████████████████████████████████████████████████| 179538/179538 [00:35<00:00, 5005.37it/s]
# 100%|█████████████████████████████████████████████████████████████| 6495/6495 [17:25<00:00,  6.21it/s]
# 100%|█████████████████████████████████████████████████████| 179538/179538 [00:00<00:00, 202694.92it/s]
# CPU times: user 5h 57min 43s, sys: 20min 41s, total: 6h 18min 24s
# Wall time: 37min 20s
# Applying actions for step 3
# 100%|████████████████████████████████████████████████████████| 179538/179538 [08:39<00:00, 345.35it/s]

# %% [markdown]
# # Analysis

# %%
all_keys = np.array(list(trajectory_dict.keys()))
# GED_dict = {}
sim_dict = {}

def my_convenient_similarity_fn(s1, m2):
    return similarity(Chem.MolFromSmiles(s1), m2)

with Pool(30) as p:
    for i in tqdm.tqdm(range(target_list.shape[0])):
        target_mol = Chem.MolFromSmiles(target_list[i])
        
        # Do it for the source mol
        sim_dict[str(i)] = my_convenient_similarity_fn(trajectory_dict[str(i)], target_mol)
        
        # Get for others
        key_for_i = list(filter(lambda x: x.startswith(str(i)+'_'), all_keys))
        for _i, sim in enumerate(p.imap(functools.partial(my_convenient_similarity_fn, m2=target_mol), np.vectorize(trajectory_dict.get)(key_for_i))):
            sim_dict[key_for_i[_i]] = sim
# Out:
# 100%|█████████████████████████████████████████████████████████████| 1928/1928 [41:02<00:00,  1.28s/it]

# %%
rand_idx = np.random.randint(0, 1000, (5,))

for r in rand_idx:
    print("#"*150)
    print(r)
    print("source")
    display(Chem.MolFromSmiles(trajectory_dict[str(r)]))
    print("target")
    display(Chem.MolFromSmiles(target_list[r]))
    
    keys_for_r = np.array(list(filter(lambda x: x.startswith(str(r)+'_'), all_keys)))
    sim_for_r = np.vectorize(sim_dict.get)(keys_for_r)
    
    print(f"sim = 1: {(sim_for_r == 1).sum()} | sim >= 0.9: {(sim_for_r >= 0.9).sum()} | sim >= 0.8: {(sim_for_r >= 0.8).sum()}")
    
    print("-"*50)
    print(f"Steps for highest sim = {sim_for_r.max():.2f}")
    key = keys_for_r[(sim_for_r == sim_for_r.max())][0]
    
    traj_idxes = key.split('_')
    for i in range(1, len(traj_idxes)+1):
        key = "_".join(traj_idxes[:i])
        print(f"Sim = {sim_dict[key]:.2f}")
        display(Chem.MolFromSmiles(trajectory_dict[key]))
# Out:
# ######################################################################################################################################################
# 941
# source
# target
# sim = 1: 1 | sim >= 0.9: 1 | sim >= 0.8: 1
# --------------------------------------------------
# Steps for highest sim = 1.00
# Sim = 0.29
# Sim = 0.66
# Sim = 1.00
# ######################################################################################################################################################
# 795
# source
# target
# sim = 1: 1 | sim >= 0.9: 1 | sim >= 0.8: 3
# --------------------------------------------------
# Steps for highest sim = 1.00
# Sim = 0.47
# Sim = 0.77
# Sim = 1.00
# ######################################################################################################################################################
# 842
# source
# target
# sim = 1: 0 | sim >= 0.9: 0 | sim >= 0.8: 0
# --------------------------------------------------
# Steps for highest sim = 0.78
# Sim = 0.22
# Sim = 0.43
# Sim = 0.78
# ######################################################################################################################################################
# 379
# source
# target
# sim = 1: 1 | sim >= 0.9: 1 | sim >= 0.8: 27
# --------------------------------------------------
# Steps for highest sim = 1.00
# Sim = 0.45
# Sim = 0.71
# Sim = 1.00
# ######################################################################################################################################################
# 248
# source
# target
# sim = 1: 0 | sim >= 0.9: 0 | sim >= 0.8: 0
# --------------------------------------------------
# Steps for highest sim = 0.73
# Sim = 0.28
# Sim = 0.57
# Sim = 0.73

# %%
# %matplotlib inline
import seaborn as sns
from matplotlib import pyplot as plt

sim_vals = np.array(list(sim_dict.values()))
sns.displot(sim_vals, kde=True, bins=50)
plt.title("All similarities")
plt.xlabel("tanimoto sim over morgan fp")
plt.show()

# %%
stepwise_keys = {}
for step in range(0, 4):
    stepwise_keys[step] = set(list(filter(lambda x: len(x.split('_')) == step+1, all_keys)))
    

source_index_wise_keys = {}
for i in tqdm.tqdm(range(len(target_list))):
    source_index_wise_keys[i] = set(list(filter(lambda x: x == str(i) or x.startswith(str(i)+'_'), all_keys)))
# Out:
# 100%|█████████████████████████████████████████████████████████████| 1928/1928 [42:58<00:00,  1.34s/it]

# %%
best_sim_list = []
step_for_best_sim_list = []

for i in tqdm.tqdm(range(len(target_list))):
    keys_for_i = list(filter(lambda x: len(x.split("_")) > 1, list(source_index_wise_keys[i])))
    sim_list_for_i = np.vectorize(sim_dict.get)(keys_for_i)
    
    best_arg = sim_list_for_i.argmax()
    best_sim_list.append(sim_list_for_i[best_arg])
    step_for_best_sim_list.append(len(keys_for_i[best_arg].split("_"))-1)

best_sim_list = np.array(best_sim_list)
step_for_best_sim_list = np.array(step_for_best_sim_list)
print(f"Average best sim = {np.mean(best_sim_list)}")
print(f"% correct paths predicted = {(best_sim_list==1).sum()/best_sim_list.shape[0]*100}")
print(f"Average path length for best sim = {np.mean(step_for_best_sim_list)}")
# Out:
# 100%|███████████████████████████████████████████████████████████| 1928/1928 [00:01<00:00, 1054.28it/s]
# Average best sim = 0.8112332725049874
# % correct paths predicted = 37.60373443983403
# Average path length for best sim = 2.194502074688797

# %% [markdown]
# The above value is differerent from p*\*n that could be expected from the results sheet
# \- step 2: %rank<=10 = 75%
# So we may expect 75% correct for step 1 and 75% correct for step 2 => (0.75 * 0.75) ~= 56% correct trajectories.
# But after step 1, the wrong 25% no longer have 75% accuracy for next step => (0.75 * x) ~= 37.6%  || Solving gives 50%

# %%
# %matplotlib inline
import seaborn as sns
from matplotlib import pyplot as plt

sns.displot(best_sim_list, kde=True, bins=50)
plt.title("All similarities")
plt.xlabel("tanimoto sim over morgan fp")
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.histplot(pd.DataFrame({"steps": step_for_best_sim_list, "sim": best_sim_list}), x="sim", hue='steps', multiple='dodge', shrink=0.7, palette=sns.color_palette())
plt.ylabel("step count")
plt.xlabel("Similarity")
plt.title("Step count at different similarity values for best paths")
plt.show()
# Out:
# /home/abhor/miniconda3/envs/de_novo/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.

# %% [markdown]
# ### There are 2 step paths that were completed in 1 step!? (sim = 1 & step = 1)
# It found shorter paths!!!!!

# %%
indices = np.where((best_sim_list == 1) & (step_for_best_sim_list == 1))[0]
print(f"There are {indices.shape} such indices.")

for i in indices:
    print("#"*150)
    print(i)
    print("Actual")
    
#     display(Chem.AllChem.ReactionFromSmarts(f"{trajectory_dict[str(i)]}>>{target_list[i]}", useSmiles=True))
#     display(Chem.MolFromSmiles(trajectory_dict[str(r)]))
#     print("target")
#     display(Chem.MolFromSmiles(target_list[r]))
    
#     keys_for_r = np.array(list(filter(lambda x: x.startswith(str(r)+'_'), all_keys)))
#     sim_for_r = np.vectorize(sim_dict.get)(keys_for_r)
    
#     print(f"sim = 1: {(sim_for_r == 1).sum()} | sim >= 0.9: {(sim_for_r >= 0.9).sum()} | sim >= 0.8: {(sim_for_r >= 0.8).sum()}")
    
#     print("-"*50)
#     print(f"Steps for highest sim = {sim_for_r.max():.2f}")
#     key = keys_for_r[(sim_for_r == sim_for_r.max())][0]
    
#     traj_idxes = key.split('_')
#     for i in range(1, len(traj_idxes)+1):
#         key = "_".join(traj_idxes[:i])
#         print(f"Sim = {sim_dict[key]:.2f}")
#         display(Chem.MolFromSmiles(trajectory_dict[key]))
# Out:
# There are (9,) such indices.
# ######################################################################################################################################################
# 63
# Actual
# ######################################################################################################################################################
# 70
# Actual
# ######################################################################################################################################################
# 82
# Actual
# ######################################################################################################################################################
# 114
# Actual
# ######################################################################################################################################################
# 139
# Actual
# ######################################################################################################################################################
# 422
# Actual
# ######################################################################################################################################################
# 1168
# Actual
# ######################################################################################################################################################
# 1656
# Actual
# ######################################################################################################################################################
# 1815
# Actual

# %% [markdown]
# # Trying to figure out a way to limit branching

# %%
for key in stepwise_keys.keys():
    if key == 0:
        continue
    print("Step =", key) 
    temp_sim = np.vectorize(sim_dict.get)(list(stepwise_keys[key]))
    print(f"Overall: min={temp_sim.min():.2f} || max={temp_sim.max():.2f} || mean={temp_sim.mean():.2f}")
    
    temp_sim = best_sim_list[step_for_best_sim_list == key]
    print(f"Best:    min={temp_sim.min():.2f} || max={temp_sim.max():.2f} || mean={temp_sim.mean():.2f}")
    print()
# Out:
# Step = 1
# Overall: min=0.08 || max=1.00 || mean=0.47
# Best:    min=0.40 || max=1.00 || mean=0.70
#
# Step = 2
# Overall: min=0.04 || max=1.00 || mean=0.44
# Best:    min=0.25 || max=1.00 || mean=0.86
#
# Step = 3
# Overall: min=0.03 || max=1.00 || mean=0.39
# Best:    min=0.34 || max=1.00 || mean=0.75

# %%
for i in list(source_index_wise_keys.keys()):
    print("Source target idx =", i)
    keys_for_i = list(filter(lambda x: len(x.split("_")) > 1, list(source_index_wise_keys[i])))
    sim_list_for_i = np.vectorize(sim_dict.get)(keys_for_i)
    best_arg = sim_list_for_i.argmax()
    best_key = keys_for_i[best_arg]
    best_path_idx = best_key.split("_")
    best_path_sim = [sim_dict["_".join(best_path_idx[:_i+1])] for _i in range(len(best_path_idx))]
    print("Best path sim", " --> ".join([f"{sim:.2f}" for sim in best_path_sim]))
    
    average_path_sim = [best_path_sim[0]]
    order_of_best_sim = [1]
    total_order_of_best_sim = [1]
    for _i in range(1, len(best_path_sim)):
        sim = np.vectorize(sim_dict.get)(list(source_index_wise_keys[i].intersection(stepwise_keys[_i])))
        sim = np.sort(sim)[::-1]
        order_of_best_sim.append(np.where(sim == best_path_sim[_i])[0][0] + 1)
        total_order_of_best_sim.append(sim.shape[0])
        sim = sim.mean()
        average_path_sim.append(sim)
    print("Average path sim = ", " --> ".join([f"{sim:.2f}" for sim in average_path_sim]))
    print("Order of best sim  =", " --> ".join([f"{o}/{t}" for o, t in zip(order_of_best_sim, total_order_of_best_sim)]))
    print()
# Out:
# Source target idx = 0
# Best path sim 0.34 --> 0.67 --> 1.00
# Average path sim =  0.34 --> 0.44 --> 0.41
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1
# Best path sim 0.45 --> 0.45 --> 0.66
# Average path sim =  0.45 --> 0.44 --> 0.43
# Order of best sim  = 1/1 --> 5/10 --> 1/100
#
# Source target idx = 2
# Best path sim 0.44 --> 0.65 --> 0.64 --> 1.00
# Average path sim =  0.44 --> 0.54 --> 0.59 --> 0.55
# Order of best sim  = 1/1 --> 1/10 --> 20/91 --> 1/798
#
# Source target idx = 3
# Best path sim 0.26 --> 0.74 --> 1.00
# Average path sim =  0.26 --> 0.40 --> 0.39
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 4
# Best path sim 0.34 --> 0.77 --> 1.00
# Average path sim =  0.34 --> 0.47 --> 0.41
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 5
# Best path sim 0.52 --> 0.40 --> 0.52 --> 0.54
# Average path sim =  0.52 --> 0.43 --> 0.36 --> 0.33
# Order of best sim  = 1/1 --> 9/10 --> 2/54 --> 1/259
#
# Source target idx = 6
# Best path sim 0.27 --> 0.68 --> 1.00
# Average path sim =  0.27 --> 0.39 --> 0.43
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 7
# Best path sim 0.22 --> 0.46 --> 0.77
# Average path sim =  0.22 --> 0.40 --> 0.46
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 8
# Best path sim 0.35 --> 0.51 --> 0.47 --> 0.52
# Average path sim =  0.35 --> 0.33 --> 0.32 --> 0.30
# Order of best sim  = 1/1 --> 1/10 --> 5/88 --> 1/830
#
# Source target idx = 9
# Best path sim 0.33 --> 0.73 --> 1.00
# Average path sim =  0.33 --> 0.38 --> 0.41
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 10
# Best path sim 0.11 --> 0.53 --> 1.00
# Average path sim =  0.11 --> 0.32 --> 0.41
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 11
# Best path sim 0.53 --> 0.48 --> 0.41 --> 0.60
# Average path sim =  0.53 --> 0.44 --> 0.43 --> 0.37
# Order of best sim  = 1/1 --> 2/10 --> 28/42 --> 1/212
#
# Source target idx = 12
# Best path sim 0.33 --> 0.72
# Average path sim =  0.33 --> 0.46
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 13
# Best path sim 0.35 --> 0.77
# Average path sim =  0.35 --> 0.51
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 14
# Best path sim 0.46 --> 0.59 --> 1.00
# Average path sim =  0.46 --> 0.48 --> 0.54
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 15
# Best path sim 0.35 --> 0.48 --> 0.64
# Average path sim =  0.35 --> 0.32 --> 0.31
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 16
# Best path sim 0.35 --> 0.54 --> 1.00
# Average path sim =  0.35 --> 0.38 --> 0.43
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 17
# Best path sim 0.41 --> 0.66 --> 1.00
# Average path sim =  0.41 --> 0.56 --> 0.51
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 18
# Best path sim 0.55 --> 0.48
# Average path sim =  0.55 --> 0.44
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 19
# Best path sim 0.49 --> 0.82 --> 0.91 --> 1.00
# Average path sim =  0.49 --> 0.50 --> 0.48 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/967
#
# Source target idx = 20
# Best path sim 0.33 --> 0.69
# Average path sim =  0.33 --> 0.56
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 21
# Best path sim 0.56 --> 0.55 --> 0.68 --> 0.73
# Average path sim =  0.56 --> 0.55 --> 0.53 --> 0.48
# Order of best sim  = 1/1 --> 4/10 --> 2/100 --> 1/614
#
# Source target idx = 22
# Best path sim 0.31 --> 0.81 --> 1.00
# Average path sim =  0.31 --> 0.50 --> 0.52
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 23
# Best path sim 0.54 --> 0.66 --> 0.86
# Average path sim =  0.54 --> 0.58 --> 0.55
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 24
# Best path sim 0.17 --> 0.38 --> 0.78
# Average path sim =  0.17 --> 0.31 --> 0.40
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 25
# Best path sim 0.55 --> 0.77 --> 0.87
# Average path sim =  0.55 --> 0.56 --> 0.53
# Order of best sim  = 1/1 --> 1/10 --> 1/91
#
# Source target idx = 26
# Best path sim 0.41 --> 0.63 --> 1.00
# Average path sim =  0.41 --> 0.51 --> 0.56
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 27
# Best path sim 0.49 --> 0.52 --> 0.53 --> 0.57
# Average path sim =  0.49 --> 0.45 --> 0.44 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 2/49 --> 1/441
#
# Source target idx = 28
# Best path sim 0.65 --> 0.59 --> 0.72
# Average path sim =  0.65 --> 0.52 --> 0.49
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 29
# Best path sim 0.24 --> 0.52 --> 1.00
# Average path sim =  0.24 --> 0.28 --> 0.35
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 30
# Best path sim 0.41 --> 0.76 --> 1.00
# Average path sim =  0.41 --> 0.53 --> 0.50
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 31
# Best path sim 0.63 --> 0.79 --> 0.85
# Average path sim =  0.63 --> 0.59 --> 0.55
# Order of best sim  = 1/1 --> 1/10 --> 1/80
#
# Source target idx = 32
# Best path sim 0.22 --> 0.43 --> 0.56
# Average path sim =  0.22 --> 0.34 --> 0.39
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 33
# Best path sim 0.46 --> 0.61 --> 0.61 --> 0.61
# Average path sim =  0.46 --> 0.45 --> 0.37 --> 0.30
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/1000
#
# Source target idx = 34
# Best path sim 0.20 --> 0.62 --> 1.00
# Average path sim =  0.20 --> 0.30 --> 0.30
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 35
# Best path sim 0.45 --> 0.81 --> 1.00
# Average path sim =  0.45 --> 0.55 --> 0.56
# Order of best sim  = 1/1 --> 1/10 --> 1/39
#
# Source target idx = 36
# Best path sim 0.39 --> 0.82 --> 1.00
# Average path sim =  0.39 --> 0.46 --> 0.45
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 37
# Best path sim 0.28 --> 0.34 --> 0.59
# Average path sim =  0.28 --> 0.30 --> 0.31
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 38
# Best path sim 0.60 --> 0.69 --> 0.69 --> 0.71
# Average path sim =  0.60 --> 0.55 --> 0.55 --> 0.49
# Order of best sim  = 1/1 --> 1/10 --> 4/100 --> 1/1000
#
# Source target idx = 39
# Best path sim 0.22 --> 0.50
# Average path sim =  0.22 --> 0.43
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 40
# Best path sim 0.34 --> 0.81 --> 1.00
# Average path sim =  0.34 --> 0.37 --> 0.35
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 41
# Best path sim 0.35 --> 0.51 --> 0.76
# Average path sim =  0.35 --> 0.48 --> 0.46
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 42
# Best path sim 0.45 --> 0.44 --> 0.61 --> 0.70
# Average path sim =  0.45 --> 0.43 --> 0.42 --> 0.39
# Order of best sim  = 1/1 --> 5/10 --> 1/100 --> 1/1000
#
# Source target idx = 43
# Best path sim 0.54 --> 0.84 --> 0.75 --> 0.89
# Average path sim =  0.54 --> 0.62 --> 0.56 --> 0.53
# Order of best sim  = 1/1 --> 1/10 --> 6/94 --> 1/698
#
# Source target idx = 44
# Best path sim 0.24 --> 0.41 --> 0.48
# Average path sim =  0.24 --> 0.35 --> 0.33
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 45
# Best path sim 0.24 --> 0.60 --> 0.77
# Average path sim =  0.24 --> 0.44 --> 0.40
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 46
# Best path sim 0.51 --> 0.51 --> 0.58
# Average path sim =  0.51 --> 0.45 --> 0.41
# Order of best sim  = 1/1 --> 2/10 --> 1/77
#
# Source target idx = 47
# Best path sim 0.20 --> 0.23 --> 0.71 --> 0.72
# Average path sim =  0.20 --> 0.20 --> 0.21 --> 0.18
# Order of best sim  = 1/1 --> 2/10 --> 1/100 --> 1/607
#
# Source target idx = 48
# Best path sim 0.53 --> 0.58 --> 0.78
# Average path sim =  0.53 --> 0.51 --> 0.48
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 49
# Best path sim 0.50 --> 0.77 --> 0.83 --> 1.00
# Average path sim =  0.50 --> 0.48 --> 0.45 --> 0.41
# Order of best sim  = 1/1 --> 1/10 --> 3/100 --> 1/1000
#
# Source target idx = 50
# Best path sim 0.52 --> 0.52 --> 0.69 --> 0.74
# Average path sim =  0.52 --> 0.50 --> 0.49 --> 0.45
# Order of best sim  = 1/1 --> 5/10 --> 1/100 --> 1/1000
#
# Source target idx = 51
# Best path sim 0.42 --> 0.78 --> 1.00
# Average path sim =  0.42 --> 0.43 --> 0.33
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 52
# Best path sim 0.54 --> 0.63
# Average path sim =  0.54 --> 0.53
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 53
# Best path sim 0.37 --> 0.48 --> 0.52 --> 0.73
# Average path sim =  0.37 --> 0.47 --> 0.48 --> 0.44
# Order of best sim  = 1/1 --> 4/10 --> 22/100 --> 1/972
#
# Source target idx = 54
# Best path sim 0.25 --> 0.59 --> 1.00
# Average path sim =  0.25 --> 0.36 --> 0.34
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 55
# Best path sim 0.51 --> 0.53 --> 0.50 --> 0.72
# Average path sim =  0.51 --> 0.48 --> 0.46 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 20/100 --> 1/889
#
# Source target idx = 56
# Best path sim 0.46 --> 0.46 --> 0.75
# Average path sim =  0.46 --> 0.43 --> 0.40
# Order of best sim  = 1/1 --> 4/10 --> 1/100
#
# Source target idx = 57
# Best path sim 0.49 --> 0.73 --> 0.73 --> 0.86
# Average path sim =  0.49 --> 0.65 --> 0.56 --> 0.51
# Order of best sim  = 1/1 --> 1/10 --> 1/53 --> 1/346
#
# Source target idx = 58
# Best path sim 0.29 --> 0.63 --> 1.00
# Average path sim =  0.29 --> 0.46 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 59
# Best path sim 0.59 --> 0.71 --> 0.79 --> 0.81
# Average path sim =  0.59 --> 0.63 --> 0.60 --> 0.56
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/997
#
# Source target idx = 60
# Best path sim 0.35 --> 0.72 --> 1.00
# Average path sim =  0.35 --> 0.41 --> 0.43
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 61
# Best path sim 0.56 --> 0.68 --> 0.70 --> 0.71
# Average path sim =  0.56 --> 0.59 --> 0.55 --> 0.50
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/1000
#
# Source target idx = 62
# Best path sim 0.45 --> 0.80 --> 1.00
# Average path sim =  0.45 --> 0.51 --> 0.47
# Order of best sim  = 1/1 --> 1/10 --> 1/73
#
# Source target idx = 63
# Best path sim 0.57 --> 1.00
# Average path sim =  0.57 --> 0.77
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 64
# Best path sim 0.33 --> 0.55 --> 0.58 --> 0.62
# Average path sim =  0.33 --> 0.48 --> 0.38 --> 0.35
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/895
#
# Source target idx = 65
# Best path sim 0.15 --> 0.22 --> 0.52
# Average path sim =  0.15 --> 0.21 --> 0.25
# Order of best sim  = 1/1 --> 3/10 --> 1/100
#
# Source target idx = 66
# Best path sim 0.26 --> 0.32 --> 0.43
# Average path sim =  0.26 --> 0.30 --> 0.24
# Order of best sim  = 1/1 --> 4/10 --> 1/100
#
# Source target idx = 67
# Best path sim 0.43 --> 0.79 --> 1.00
# Average path sim =  0.43 --> 0.54 --> 0.54
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 68
# Best path sim 0.25 --> 0.71 --> 1.00 --> 1.00
# Average path sim =  0.25 --> 0.40 --> 0.38 --> 0.33
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/1000
#
# Source target idx = 69
# Best path sim 0.24 --> 0.60 --> 0.74
# Average path sim =  0.24 --> 0.32 --> 0.35
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 70
# Best path sim 0.63 --> 1.00
# Average path sim =  0.63 --> 0.65
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 71
# Best path sim 0.27 --> 0.77 --> 1.00
# Average path sim =  0.27 --> 0.47 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 72
# Best path sim 0.45 --> 0.75 --> 0.91 --> 1.00
# Average path sim =  0.45 --> 0.49 --> 0.52 --> 0.48
# Order of best sim  = 1/1 --> 1/10 --> 2/100 --> 1/996
#
# Source target idx = 73
# Best path sim 0.48 --> 0.80 --> 1.00
# Average path sim =  0.48 --> 0.54 --> 0.53
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 74
# Best path sim 0.40 --> 0.44 --> 0.69
# Average path sim =  0.40 --> 0.38 --> 0.40
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 75
# Best path sim 0.42 --> 0.59 --> 0.82
# Average path sim =  0.42 --> 0.47 --> 0.43
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 76
# Best path sim 0.41 --> 0.59 --> 0.53 --> 0.73
# Average path sim =  0.41 --> 0.43 --> 0.42 --> 0.39
# Order of best sim  = 1/1 --> 1/10 --> 8/70 --> 1/586
#
# Source target idx = 77
# Best path sim 0.56 --> 0.85 --> 0.87
# Average path sim =  0.56 --> 0.65 --> 0.66
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 78
# Best path sim 0.44 --> 0.53 --> 0.60
# Average path sim =  0.44 --> 0.47 --> 0.45
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 79
# Best path sim 0.64 --> 0.79 --> 0.81 --> 0.87
# Average path sim =  0.64 --> 0.71 --> 0.65 --> 0.59
# Order of best sim  = 1/1 --> 2/10 --> 3/93 --> 1/770
#
# Source target idx = 80
# Best path sim 0.58 --> 0.76 --> 0.68 --> 0.78
# Average path sim =  0.58 --> 0.62 --> 0.53 --> 0.49
# Order of best sim  = 1/1 --> 1/10 --> 9/100 --> 1/902
#
# Source target idx = 81
# Best path sim 0.65 --> 0.50 --> 0.52
# Average path sim =  0.65 --> 0.43 --> 0.37
# Order of best sim  = 1/1 --> 1/10 --> 1/97
#
# Source target idx = 82
# Best path sim 0.69 --> 1.00
# Average path sim =  0.69 --> 0.79
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 83
# Best path sim 0.53 --> 0.63
# Average path sim =  0.53 --> 0.56
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 84
# Best path sim 0.20 --> 0.26 --> 0.34 --> 0.57
# Average path sim =  0.20 --> 0.31 --> 0.31 --> 0.31
# Order of best sim  = 1/1 --> 7/10 --> 27/100 --> 1/899
#
# Source target idx = 85
# Best path sim 0.31 --> 0.37 --> 0.71
# Average path sim =  0.31 --> 0.32 --> 0.37
# Order of best sim  = 1/1 --> 3/10 --> 1/100
#
# Source target idx = 86
# Best path sim 0.57 --> 0.76 --> 1.00
# Average path sim =  0.57 --> 0.56 --> 0.54
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 87
# Best path sim 0.54 --> 0.56 --> 0.73
# Average path sim =  0.54 --> 0.55 --> 0.52
# Order of best sim  = 1/1 --> 4/10 --> 1/100
#
# Source target idx = 88
# Best path sim 0.55 --> 0.56 --> 0.64 --> 0.68
# Average path sim =  0.55 --> 0.54 --> 0.55 --> 0.54
# Order of best sim  = 1/1 --> 3/10 --> 7/100 --> 1/762
#
# Source target idx = 89
# Best path sim 0.18 --> 0.51 --> 1.00
# Average path sim =  0.18 --> 0.27 --> 0.33
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 90
# Best path sim 0.64 --> 0.62 --> 0.59 --> 0.65
# Average path sim =  0.64 --> 0.60 --> 0.56 --> 0.53
# Order of best sim  = 1/1 --> 1/10 --> 7/34 --> 1/202
#
# Source target idx = 91
# Best path sim 0.48 --> 0.74 --> 0.80
# Average path sim =  0.48 --> 0.53 --> 0.53
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 92
# Best path sim 0.35 --> 0.50 --> 0.69
# Average path sim =  0.35 --> 0.44 --> 0.43
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 93
# Best path sim 0.58 --> 0.66 --> 1.00
# Average path sim =  0.58 --> 0.64 --> 0.57
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 94
# Best path sim 0.21 --> 0.46 --> 1.00
# Average path sim =  0.21 --> 0.23 --> 0.26
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 95
# Best path sim 0.42 --> 0.62 --> 0.87 --> 1.00
# Average path sim =  0.42 --> 0.46 --> 0.43 --> 0.41
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/1000
#
# Source target idx = 96
# Best path sim 0.24 --> 0.61 --> 1.00
# Average path sim =  0.24 --> 0.36 --> 0.38
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 97
# Best path sim 0.60 --> 0.67 --> 0.67
# Average path sim =  0.60 --> 0.58 --> 0.50
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 98
# Best path sim 0.60 --> 0.81
# Average path sim =  0.60 --> 0.64
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 99
# Best path sim 0.75 --> 0.81 --> 1.00
# Average path sim =  0.75 --> 0.70 --> 0.60
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 100
# Best path sim 0.34 --> 0.54 --> 0.61 --> 0.82
# Average path sim =  0.34 --> 0.51 --> 0.48 --> 0.45
# Order of best sim  = 1/1 --> 6/10 --> 6/100 --> 1/1000
#
# Source target idx = 101
# Best path sim 0.42 --> 0.62 --> 0.72 --> 0.79
# Average path sim =  0.42 --> 0.48 --> 0.47 --> 0.43
# Order of best sim  = 1/1 --> 2/10 --> 2/100 --> 1/898
#
# Source target idx = 102
# Best path sim 0.37 --> 0.77 --> 0.77 --> 1.00
# Average path sim =  0.37 --> 0.48 --> 0.47 --> 0.43
# Order of best sim  = 1/1 --> 1/10 --> 3/100 --> 1/1000
#
# Source target idx = 103
# Best path sim 0.72 --> 0.86 --> 1.00
# Average path sim =  0.72 --> 0.72 --> 0.67
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 104
# Best path sim 0.46 --> 0.80 --> 0.80 --> 1.00
# Average path sim =  0.46 --> 0.59 --> 0.51 --> 0.44
# Order of best sim  = 1/1 --> 1/10 --> 5/100 --> 1/1000
#
# Source target idx = 105
# Best path sim 0.26 --> 0.41 --> 0.69
# Average path sim =  0.26 --> 0.43 --> 0.46
# Order of best sim  = 1/1 --> 6/10 --> 1/100
#
# Source target idx = 106
# Best path sim 0.13 --> 0.18 --> 0.54
# Average path sim =  0.13 --> 0.18 --> 0.21
# Order of best sim  = 1/1 --> 3/10 --> 1/91
#
# Source target idx = 107
# Best path sim 0.47 --> 0.73 --> 1.00
# Average path sim =  0.47 --> 0.55 --> 0.59
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 108
# Best path sim 0.27 --> 0.43 --> 0.68
# Average path sim =  0.27 --> 0.37 --> 0.37
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 109
# Best path sim 0.25 --> 0.65 --> 1.00
# Average path sim =  0.25 --> 0.38 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 110
# Best path sim 0.46 --> 0.82 --> 0.83
# Average path sim =  0.46 --> 0.50 --> 0.44
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 111
# Best path sim 0.51 --> 0.76 --> 1.00
# Average path sim =  0.51 --> 0.62 --> 0.62
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 112
# Best path sim 0.43 --> 0.65 --> 1.00
# Average path sim =  0.43 --> 0.43 --> 0.43
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 113
# Best path sim 0.37 --> 0.57 --> 0.49 --> 0.75
# Average path sim =  0.37 --> 0.48 --> 0.37 --> 0.32
# Order of best sim  = 1/1 --> 1/10 --> 11/100 --> 1/671
#
# Source target idx = 114
# Best path sim 0.59 --> 1.00
# Average path sim =  0.59 --> 0.71
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 115
# Best path sim 0.35 --> 0.39 --> 0.74
# Average path sim =  0.35 --> 0.39 --> 0.47
# Order of best sim  = 1/1 --> 5/10 --> 1/100
#
# Source target idx = 116
# Best path sim 0.27 --> 0.55 --> 0.92
# Average path sim =  0.27 --> 0.33 --> 0.37
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 117
# Best path sim 0.60 --> 0.73
# Average path sim =  0.60 --> 0.65
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 118
# Best path sim 0.29 --> 0.81 --> 1.00
# Average path sim =  0.29 --> 0.42 --> 0.41
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 119
# Best path sim 0.12 --> 0.28 --> 0.46 --> 0.56
# Average path sim =  0.12 --> 0.26 --> 0.26 --> 0.25
# Order of best sim  = 1/1 --> 4/10 --> 3/83 --> 1/660
#
# Source target idx = 120
# Best path sim 0.36 --> 0.72 --> 1.00
# Average path sim =  0.36 --> 0.51 --> 0.49
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 121
# Best path sim 0.52 --> 0.68 --> 0.76
# Average path sim =  0.52 --> 0.57 --> 0.53
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 122
# Best path sim 0.54 --> 0.84 --> 1.00
# Average path sim =  0.54 --> 0.65 --> 0.65
# Order of best sim  = 1/1 --> 1/10 --> 1/72
#
# Source target idx = 123
# Best path sim 0.36 --> 0.44 --> 0.50
# Average path sim =  0.36 --> 0.37 --> 0.34
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 124
# Best path sim 0.48 --> 0.68
# Average path sim =  0.48 --> 0.52
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 125
# Best path sim 0.41 --> 0.47 --> 0.57
# Average path sim =  0.41 --> 0.40 --> 0.36
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 126
# Best path sim 0.31 --> 0.72 --> 1.00
# Average path sim =  0.31 --> 0.44 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 1/45
#
# Source target idx = 127
# Best path sim 0.47 --> 0.70
# Average path sim =  0.47 --> 0.65
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 128
# Best path sim 0.65 --> 0.75 --> 0.87
# Average path sim =  0.65 --> 0.64 --> 0.59
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 129
# Best path sim 0.23 --> 0.47 --> 0.77
# Average path sim =  0.23 --> 0.36 --> 0.40
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 130
# Best path sim 0.18 --> 0.26 --> 0.66
# Average path sim =  0.18 --> 0.31 --> 0.37
# Order of best sim  = 1/1 --> 9/10 --> 1/100
#
# Source target idx = 131
# Best path sim 0.28 --> 0.65 --> 1.00
# Average path sim =  0.28 --> 0.41 --> 0.41
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 132
# Best path sim 0.49 --> 0.56 --> 0.71
# Average path sim =  0.49 --> 0.52 --> 0.50
# Order of best sim  = 1/1 --> 4/10 --> 1/100
#
# Source target idx = 133
# Best path sim 0.25 --> 0.33 --> 0.64
# Average path sim =  0.25 --> 0.34 --> 0.39
# Order of best sim  = 1/1 --> 6/10 --> 1/100
#
# Source target idx = 134
# Best path sim 0.49 --> 0.72 --> 1.00
# Average path sim =  0.49 --> 0.54 --> 0.64
# Order of best sim  = 1/1 --> 1/10 --> 1/30
#
# Source target idx = 135
# Best path sim 0.28 --> 0.28 --> 0.45
# Average path sim =  0.28 --> 0.25 --> 0.24
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 136
# Best path sim 0.23 --> 0.49 --> 0.83
# Average path sim =  0.23 --> 0.37 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 137
# Best path sim 0.44 --> 0.76 --> 1.00
# Average path sim =  0.44 --> 0.57 --> 0.48
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 138
# Best path sim 0.23 --> 0.25 --> 0.43
# Average path sim =  0.23 --> 0.23 --> 0.24
# Order of best sim  = 1/1 --> 1/10 --> 1/48
#
# Source target idx = 139
# Best path sim 0.61 --> 1.00
# Average path sim =  0.61 --> 0.77
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 140
# Best path sim 0.41 --> 0.57 --> 0.78 --> 0.83
# Average path sim =  0.41 --> 0.45 --> 0.47 --> 0.43
# Order of best sim  = 1/1 --> 1/10 --> 1/86 --> 1/596
#
# Source target idx = 141
# Best path sim 0.25 --> 0.20 --> 0.27 --> 0.71
# Average path sim =  0.25 --> 0.23 --> 0.31 --> 0.30
# Order of best sim  = 1/1 --> 9/10 --> 27/70 --> 1/540
#
# Source target idx = 142
# Best path sim 0.30 --> 0.54 --> 0.85
# Average path sim =  0.30 --> 0.45 --> 0.49
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 143
# Best path sim 0.42 --> 0.61 --> 0.86 --> 0.90
# Average path sim =  0.42 --> 0.62 --> 0.60 --> 0.55
# Order of best sim  = 1/1 --> 5/10 --> 4/100 --> 1/982
#
# Source target idx = 144
# Best path sim 0.18 --> 0.51 --> 1.00
# Average path sim =  0.18 --> 0.27 --> 0.33
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 145
# Best path sim 0.35 --> 0.78 --> 1.00
# Average path sim =  0.35 --> 0.46 --> 0.50
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 146
# Best path sim 0.19 --> 0.26 --> 0.56
# Average path sim =  0.19 --> 0.24 --> 0.31
# Order of best sim  = 1/1 --> 3/10 --> 1/100
#
# Source target idx = 147
# Best path sim 0.70 --> 0.70
# Average path sim =  0.70 --> 0.57
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 148
# Best path sim 0.43 --> 0.74 --> 1.00
# Average path sim =  0.43 --> 0.42 --> 0.38
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 149
# Best path sim 0.55 --> 0.62 --> 0.62 --> 0.73
# Average path sim =  0.55 --> 0.61 --> 0.52 --> 0.43
# Order of best sim  = 1/1 --> 5/10 --> 4/100 --> 1/1000
#
# Source target idx = 150
# Best path sim 0.26 --> 0.30 --> 0.48 --> 0.66
# Average path sim =  0.26 --> 0.31 --> 0.33 --> 0.33
# Order of best sim  = 1/1 --> 6/10 --> 9/100 --> 1/971
#
# Source target idx = 151
# Best path sim 0.16 --> 0.33 --> 0.36
# Average path sim =  0.16 --> 0.23 --> 0.23
# Order of best sim  = 1/1 --> 1/10 --> 1/43
#
# Source target idx = 152
# Best path sim 0.48 --> 0.51 --> 0.72
# Average path sim =  0.48 --> 0.50 --> 0.46
# Order of best sim  = 1/1 --> 5/10 --> 1/100
#
# Source target idx = 153
# Best path sim 0.46 --> 0.79 --> 1.00
# Average path sim =  0.46 --> 0.52 --> 0.52
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 154
# Best path sim 0.28 --> 0.63 --> 1.00
# Average path sim =  0.28 --> 0.41 --> 0.44
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 155
# Best path sim 0.22 --> 0.36 --> 1.00
# Average path sim =  0.22 --> 0.24 --> 0.26
# Order of best sim  = 1/1 --> 1/10 --> 1/75
#
# Source target idx = 156
# Best path sim 0.18 --> 0.41 --> 0.62 --> 0.69
# Average path sim =  0.18 --> 0.37 --> 0.41 --> 0.36
# Order of best sim  = 1/1 --> 3/10 --> 2/100 --> 1/1000
#
# Source target idx = 157
# Best path sim 0.62 --> 0.71 --> 0.72 --> 0.75
# Average path sim =  0.62 --> 0.58 --> 0.52 --> 0.48
# Order of best sim  = 1/1 --> 1/10 --> 1/81 --> 1/732
#
# Source target idx = 158
# Best path sim 0.16 --> 0.56 --> 1.00
# Average path sim =  0.16 --> 0.30 --> 0.35
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 159
# Best path sim 0.30 --> 0.33 --> 0.54 --> 0.55
# Average path sim =  0.30 --> 0.28 --> 0.28 --> 0.25
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/1000
#
# Source target idx = 160
# Best path sim 0.41 --> 0.74 --> 1.00
# Average path sim =  0.41 --> 0.57 --> 0.52
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 161
# Best path sim 0.26 --> 0.58 --> 1.00
# Average path sim =  0.26 --> 0.36 --> 0.37
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 162
# Best path sim 0.44 --> 0.64
# Average path sim =  0.44 --> 0.54
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 163
# Best path sim 0.45 --> 0.66
# Average path sim =  0.45 --> 0.51
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 164
# Best path sim 0.39 --> 0.55 --> 0.64 --> 0.69
# Average path sim =  0.39 --> 0.42 --> 0.41 --> 0.38
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/1000
#
# Source target idx = 165
# Best path sim 0.31 --> 0.54 --> 0.55 --> 0.64
# Average path sim =  0.31 --> 0.34 --> 0.33 --> 0.32
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/582
#
# Source target idx = 166
# Best path sim 0.32 --> 0.57 --> 0.85
# Average path sim =  0.32 --> 0.52 --> 0.54
# Order of best sim  = 1/1 --> 3/10 --> 1/100
#
# Source target idx = 167
# Best path sim 0.61 --> 0.86 --> 1.00
# Average path sim =  0.61 --> 0.57 --> 0.54
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 168
# Best path sim 0.43 --> 0.46 --> 0.60
# Average path sim =  0.43 --> 0.46 --> 0.42
# Order of best sim  = 1/1 --> 3/10 --> 1/100
#
# Source target idx = 169
# Best path sim 0.26 --> 0.27 --> 0.68 --> 0.71
# Average path sim =  0.26 --> 0.29 --> 0.36 --> 0.36
# Order of best sim  = 1/1 --> 7/10 --> 1/100 --> 1/979
#
# Source target idx = 170
# Best path sim 0.15 --> 0.49 --> 0.52
# Average path sim =  0.15 --> 0.31 --> 0.35
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 171
# Best path sim 0.68 --> 0.74
# Average path sim =  0.68 --> 0.68
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 172
# Best path sim 0.31 --> 0.81 --> 1.00
# Average path sim =  0.31 --> 0.49 --> 0.50
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 173
# Best path sim 0.23 --> 0.45 --> 0.44 --> 0.50
# Average path sim =  0.23 --> 0.36 --> 0.37 --> 0.33
# Order of best sim  = 1/1 --> 1/10 --> 7/100 --> 1/1000
#
# Source target idx = 174
# Best path sim 0.32 --> 0.41 --> 0.42 --> 0.59
# Average path sim =  0.32 --> 0.38 --> 0.33 --> 0.30
# Order of best sim  = 1/1 --> 2/10 --> 15/100 --> 1/983
#
# Source target idx = 175
# Best path sim 0.56 --> 0.83 --> 0.83 --> 0.83
# Average path sim =  0.56 --> 0.62 --> 0.53 --> 0.48
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/933
#
# Source target idx = 176
# Best path sim 0.36 --> 0.71 --> 1.00
# Average path sim =  0.36 --> 0.51 --> 0.53
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 177
# Best path sim 0.42 --> 0.72 --> 1.00
# Average path sim =  0.42 --> 0.44 --> 0.39
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 178
# Best path sim 0.50 --> 0.61 --> 0.64 --> 0.65
# Average path sim =  0.50 --> 0.56 --> 0.53 --> 0.47
# Order of best sim  = 1/1 --> 4/10 --> 3/98 --> 1/879
#
# Source target idx = 179
# Best path sim 0.32 --> 0.42
# Average path sim =  0.32 --> 0.32
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 180
# Best path sim 0.55 --> 0.60 --> 0.58 --> 0.77
# Average path sim =  0.55 --> 0.55 --> 0.50 --> 0.46
# Order of best sim  = 1/1 --> 1/10 --> 21/100 --> 1/994
#
# Source target idx = 181
# Best path sim 0.67 --> 0.72 --> 0.75
# Average path sim =  0.67 --> 0.64 --> 0.60
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 182
# Best path sim 0.33 --> 0.48 --> 0.71
# Average path sim =  0.33 --> 0.48 --> 0.43
# Order of best sim  = 1/1 --> 6/10 --> 1/100
#
# Source target idx = 183
# Best path sim 0.42 --> 0.43 --> 0.40 --> 0.67
# Average path sim =  0.42 --> 0.38 --> 0.38 --> 0.35
# Order of best sim  = 1/1 --> 2/10 --> 45/100 --> 1/905
#
# Source target idx = 184
# Best path sim 0.58 --> 0.55 --> 0.76
# Average path sim =  0.58 --> 0.60 --> 0.59
# Order of best sim  = 1/1 --> 9/10 --> 1/100
#
# Source target idx = 185
# Best path sim 0.52 --> 0.63 --> 1.00
# Average path sim =  0.52 --> 0.59 --> 0.52
# Order of best sim  = 1/1 --> 3/10 --> 1/74
#
# Source target idx = 186
# Best path sim 0.16 --> 0.22 --> 0.44
# Average path sim =  0.16 --> 0.21 --> 0.28
# Order of best sim  = 1/1 --> 4/10 --> 1/100
#
# Source target idx = 187
# Best path sim 0.57 --> 0.69 --> 0.88
# Average path sim =  0.57 --> 0.61 --> 0.57
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 188
# Best path sim 0.56 --> 0.74
# Average path sim =  0.56 --> 0.66
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 189
# Best path sim 0.17 --> 0.52 --> 1.00
# Average path sim =  0.17 --> 0.35 --> 0.39
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 190
# Best path sim 0.35 --> 0.45 --> 0.49
# Average path sim =  0.35 --> 0.39 --> 0.33
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 191
# Best path sim 0.23 --> 0.74 --> 1.00
# Average path sim =  0.23 --> 0.37 --> 0.41
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 192
# Best path sim 0.58 --> 0.71
# Average path sim =  0.58 --> 0.53
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 193
# Best path sim 0.55 --> 0.81 --> 0.93
# Average path sim =  0.55 --> 0.48 --> 0.36
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 194
# Best path sim 0.30 --> 0.66 --> 1.00 --> 1.00
# Average path sim =  0.30 --> 0.32 --> 0.26 --> 0.24
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/963
#
# Source target idx = 195
# Best path sim 0.47 --> 0.54 --> 0.56 --> 0.59
# Average path sim =  0.47 --> 0.52 --> 0.50 --> 0.45
# Order of best sim  = 1/1 --> 2/10 --> 3/100 --> 1/988
#
# Source target idx = 196
# Best path sim 0.40 --> 0.49 --> 0.68
# Average path sim =  0.40 --> 0.43 --> 0.43
# Order of best sim  = 1/1 --> 2/10 --> 1/71
#
# Source target idx = 197
# Best path sim 0.53 --> 0.74
# Average path sim =  0.53 --> 0.57
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 198
# Best path sim 0.38 --> 0.74
# Average path sim =  0.38 --> 0.41
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 199
# Best path sim 0.49 --> 0.71 --> 1.00
# Average path sim =  0.49 --> 0.47 --> 0.44
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 200
# Best path sim 0.31 --> 0.64 --> 0.64 --> 1.00
# Average path sim =  0.31 --> 0.39 --> 0.39 --> 0.37
# Order of best sim  = 1/1 --> 1/10 --> 8/100 --> 1/1000
#
# Source target idx = 201
# Best path sim 0.46 --> 0.68 --> 1.00
# Average path sim =  0.46 --> 0.55 --> 0.55
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 202
# Best path sim 0.57 --> 0.53 --> 0.80 --> 1.00
# Average path sim =  0.57 --> 0.55 --> 0.52 --> 0.49
# Order of best sim  = 1/1 --> 4/10 --> 2/72 --> 1/341
#
# Source target idx = 203
# Best path sim 0.40 --> 0.53 --> 0.73
# Average path sim =  0.40 --> 0.50 --> 0.45
# Order of best sim  = 1/1 --> 4/10 --> 1/100
#
# Source target idx = 204
# Best path sim 0.46 --> 0.73
# Average path sim =  0.46 --> 0.47
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 205
# Best path sim 0.43 --> 0.80 --> 1.00
# Average path sim =  0.43 --> 0.56 --> 0.46
# Order of best sim  = 1/1 --> 1/10 --> 1/75
#
# Source target idx = 206
# Best path sim 0.24 --> 0.73 --> 1.00
# Average path sim =  0.24 --> 0.39 --> 0.45
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 207
# Best path sim 0.56 --> 0.62 --> 0.85 --> 0.85
# Average path sim =  0.56 --> 0.55 --> 0.50 --> 0.44
# Order of best sim  = 1/1 --> 2/10 --> 1/100 --> 1/961
#
# Source target idx = 208
# Best path sim 0.46 --> 0.62 --> 0.76
# Average path sim =  0.46 --> 0.53 --> 0.50
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 209
# Best path sim 0.30 --> 0.88 --> 1.00
# Average path sim =  0.30 --> 0.49 --> 0.41
# Order of best sim  = 1/1 --> 1/10 --> 1/46
#
# Source target idx = 210
# Best path sim 0.50 --> 0.74 --> 1.00
# Average path sim =  0.50 --> 0.56 --> 0.56
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 211
# Best path sim 0.61 --> 0.80 --> 0.87
# Average path sim =  0.61 --> 0.66 --> 0.62
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 212
# Best path sim 0.54 --> 0.79 --> 0.79 --> 1.00
# Average path sim =  0.54 --> 0.55 --> 0.54 --> 0.50
# Order of best sim  = 1/1 --> 1/10 --> 7/100 --> 1/1000
#
# Source target idx = 213
# Best path sim 0.30 --> 0.65 --> 1.00
# Average path sim =  0.30 --> 0.31 --> 0.33
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 214
# Best path sim 0.29 --> 0.74 --> 1.00
# Average path sim =  0.29 --> 0.44 --> 0.43
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 215
# Best path sim 0.41 --> 0.73 --> 0.85
# Average path sim =  0.41 --> 0.53 --> 0.54
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 216
# Best path sim 0.41 --> 0.53 --> 0.76 --> 0.83
# Average path sim =  0.41 --> 0.48 --> 0.46 --> 0.35
# Order of best sim  = 1/1 --> 2/10 --> 2/100 --> 1/1000
#
# Source target idx = 217
# Best path sim 0.57 --> 0.71 --> 1.00
# Average path sim =  0.57 --> 0.59 --> 0.48
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 218
# Best path sim 0.41 --> 0.73 --> 1.00 --> 1.00
# Average path sim =  0.41 --> 0.46 --> 0.36 --> 0.29
# Order of best sim  = 1/1 --> 1/10 --> 1/59 --> 1/429
#
# Source target idx = 219
# Best path sim 0.45 --> 0.55 --> 0.47 --> 0.56
# Average path sim =  0.45 --> 0.44 --> 0.37 --> 0.33
# Order of best sim  = 1/1 --> 1/10 --> 5/100 --> 1/1000
#
# Source target idx = 220
# Best path sim 0.52 --> 0.66 --> 0.85
# Average path sim =  0.52 --> 0.53 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 221
# Best path sim 0.57 --> 0.85 --> 1.00
# Average path sim =  0.57 --> 0.63 --> 0.57
# Order of best sim  = 1/1 --> 1/10 --> 1/63
#
# Source target idx = 222
# Best path sim 0.51 --> 0.84 --> 1.00 --> 1.00
# Average path sim =  0.51 --> 0.55 --> 0.48 --> 0.44
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/996
#
# Source target idx = 223
# Best path sim 0.45 --> 0.44 --> 0.49 --> 0.72
# Average path sim =  0.45 --> 0.49 --> 0.47 --> 0.40
# Order of best sim  = 1/1 --> 8/10 --> 30/100 --> 1/1000
#
# Source target idx = 224
# Best path sim 0.44 --> 0.56 --> 0.83
# Average path sim =  0.44 --> 0.55 --> 0.55
# Order of best sim  = 1/1 --> 5/10 --> 1/75
#
# Source target idx = 225
# Best path sim 0.50 --> 0.77 --> 1.00
# Average path sim =  0.50 --> 0.57 --> 0.61
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 226
# Best path sim 0.40 --> 0.66 --> 1.00
# Average path sim =  0.40 --> 0.47 --> 0.46
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 227
# Best path sim 0.38 --> 0.53 --> 0.72 --> 0.75
# Average path sim =  0.38 --> 0.48 --> 0.48 --> 0.44
# Order of best sim  = 1/1 --> 5/10 --> 2/100 --> 1/1000
#
# Source target idx = 228
# Best path sim 0.39 --> 0.60
# Average path sim =  0.39 --> 0.43
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 229
# Best path sim 0.26 --> 0.71 --> 1.00 --> 1.00
# Average path sim =  0.26 --> 0.45 --> 0.47 --> 0.41
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/990
#
# Source target idx = 230
# Best path sim 0.53 --> 0.70 --> 1.00
# Average path sim =  0.53 --> 0.58 --> 0.57
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 231
# Best path sim 0.41 --> 0.85 --> 1.00 --> 1.00
# Average path sim =  0.41 --> 0.50 --> 0.47 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/1000
#
# Source target idx = 232
# Best path sim 0.46 --> 0.55 --> 0.66
# Average path sim =  0.46 --> 0.51 --> 0.53
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 233
# Best path sim 0.23 --> 0.54 --> 0.81
# Average path sim =  0.23 --> 0.42 --> 0.40
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 234
# Best path sim 0.43 --> 0.70 --> 1.00
# Average path sim =  0.43 --> 0.48 --> 0.46
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 235
# Best path sim 0.35 --> 0.48 --> 0.65
# Average path sim =  0.35 --> 0.46 --> 0.45
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 236
# Best path sim 0.55 --> 0.88 --> 0.85 --> 1.00
# Average path sim =  0.55 --> 0.67 --> 0.62 --> 0.57
# Order of best sim  = 1/1 --> 1/10 --> 2/100 --> 1/1000
#
# Source target idx = 237
# Best path sim 0.40 --> 0.74 --> 0.88
# Average path sim =  0.40 --> 0.44 --> 0.48
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 238
# Best path sim 0.57 --> 0.56 --> 0.56 --> 0.66
# Average path sim =  0.57 --> 0.48 --> 0.46 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 3/78 --> 1/626
#
# Source target idx = 239
# Best path sim 0.57 --> 0.75 --> 0.90
# Average path sim =  0.57 --> 0.61 --> 0.62
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 240
# Best path sim 0.39 --> 0.77 --> 1.00
# Average path sim =  0.39 --> 0.49 --> 0.45
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 241
# Best path sim 0.56 --> 0.57 --> 0.60 --> 0.66
# Average path sim =  0.56 --> 0.56 --> 0.52 --> 0.49
# Order of best sim  = 1/1 --> 4/10 --> 2/100 --> 1/984
#
# Source target idx = 242
# Best path sim 0.35 --> 0.70 --> 1.00
# Average path sim =  0.35 --> 0.40 --> 0.38
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 243
# Best path sim 0.35 --> 0.45 --> 0.61
# Average path sim =  0.35 --> 0.36 --> 0.33
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 244
# Best path sim 0.35 --> 0.50 --> 0.73
# Average path sim =  0.35 --> 0.50 --> 0.41
# Order of best sim  = 1/1 --> 7/10 --> 1/100
#
# Source target idx = 245
# Best path sim 0.40 --> 0.76 --> 0.86
# Average path sim =  0.40 --> 0.51 --> 0.52
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 246
# Best path sim 0.26 --> 0.62 --> 1.00 --> 1.00
# Average path sim =  0.26 --> 0.43 --> 0.44 --> 0.38
# Order of best sim  = 1/1 --> 2/10 --> 1/100 --> 1/992
#
# Source target idx = 247
# Best path sim 0.49 --> 0.45 --> 0.49 --> 0.53
# Average path sim =  0.49 --> 0.48 --> 0.44 --> 0.42
# Order of best sim  = 1/1 --> 7/10 --> 6/100 --> 1/1000
#
# Source target idx = 248
# Best path sim 0.28 --> 0.57 --> 0.73
# Average path sim =  0.28 --> 0.38 --> 0.40
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 249
# Best path sim 0.66 --> 0.77 --> 0.81
# Average path sim =  0.66 --> 0.71 --> 0.63
# Order of best sim  = 1/1 --> 2/10 --> 1/92
#
# Source target idx = 250
# Best path sim 0.33 --> 0.85 --> 0.81 --> 1.00
# Average path sim =  0.33 --> 0.60 --> 0.57 --> 0.53
# Order of best sim  = 1/1 --> 1/10 --> 4/100 --> 1/1000
#
# Source target idx = 251
# Best path sim 0.59 --> 0.78 --> 0.89 --> 0.91
# Average path sim =  0.59 --> 0.64 --> 0.61 --> 0.56
# Order of best sim  = 1/1 --> 1/10 --> 1/64 --> 1/362
#
# Source target idx = 252
# Best path sim 0.51 --> 0.48 --> 0.58 --> 0.72
# Average path sim =  0.51 --> 0.44 --> 0.45 --> 0.41
# Order of best sim  = 1/1 --> 2/10 --> 7/100 --> 1/1000
#
# Source target idx = 253
# Best path sim 0.58 --> 0.61 --> 0.65 --> 0.67
# Average path sim =  0.58 --> 0.57 --> 0.52 --> 0.46
# Order of best sim  = 1/1 --> 4/10 --> 2/75 --> 1/528
#
# Source target idx = 254
# Best path sim 0.19 --> 0.55 --> 0.90 --> 1.00
# Average path sim =  0.19 --> 0.28 --> 0.30 --> 0.24
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/1000
#
# Source target idx = 255
# Best path sim 0.40 --> 0.49 --> 0.49 --> 0.55
# Average path sim =  0.40 --> 0.39 --> 0.39 --> 0.37
# Order of best sim  = 1/1 --> 1/10 --> 5/100 --> 1/1000
#
# Source target idx = 256
# Best path sim 0.60 --> 0.82 --> 0.88
# Average path sim =  0.60 --> 0.58 --> 0.57
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 257
# Best path sim 0.48 --> 0.66 --> 0.83
# Average path sim =  0.48 --> 0.59 --> 0.59
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 258
# Best path sim 0.39 --> 0.83 --> 1.00
# Average path sim =  0.39 --> 0.52 --> 0.49
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 259
# Best path sim 0.22 --> 0.53 --> 1.00
# Average path sim =  0.22 --> 0.34 --> 0.39
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 260
# Best path sim 0.36 --> 0.73 --> 1.00
# Average path sim =  0.36 --> 0.38 --> 0.33
# Order of best sim  = 1/1 --> 1/10 --> 1/49
#
# Source target idx = 261
# Best path sim 0.51 --> 0.49 --> 0.47 --> 0.53
# Average path sim =  0.51 --> 0.42 --> 0.37 --> 0.34
# Order of best sim  = 1/1 --> 1/10 --> 10/100 --> 1/918
#
# Source target idx = 262
# Best path sim 0.43 --> 0.81 --> 1.00
# Average path sim =  0.43 --> 0.49 --> 0.46
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 263
# Best path sim 0.45 --> 0.73 --> 0.73 --> 1.00
# Average path sim =  0.45 --> 0.54 --> 0.49 --> 0.43
# Order of best sim  = 1/1 --> 1/10 --> 7/100 --> 1/1000
#
# Source target idx = 264
# Best path sim 0.38 --> 0.80 --> 1.00
# Average path sim =  0.38 --> 0.49 --> 0.46
# Order of best sim  = 1/1 --> 1/10 --> 1/48
#
# Source target idx = 265
# Best path sim 0.39 --> 0.65 --> 1.00
# Average path sim =  0.39 --> 0.42 --> 0.30
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 266
# Best path sim 0.15 --> 0.52 --> 1.00
# Average path sim =  0.15 --> 0.25 --> 0.28
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 267
# Best path sim 0.32 --> 0.42 --> 0.43 --> 0.56
# Average path sim =  0.32 --> 0.35 --> 0.32 --> 0.30
# Order of best sim  = 1/1 --> 1/10 --> 3/86 --> 1/773
#
# Source target idx = 268
# Best path sim 0.30 --> 0.58 --> 1.00
# Average path sim =  0.30 --> 0.39 --> 0.28
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 269
# Best path sim 0.55 --> 0.76 --> 1.00
# Average path sim =  0.55 --> 0.60 --> 0.59
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 270
# Best path sim 0.55 --> 0.67 --> 0.73 --> 0.79
# Average path sim =  0.55 --> 0.62 --> 0.60 --> 0.55
# Order of best sim  = 1/1 --> 3/10 --> 5/100 --> 1/1000
#
# Source target idx = 271
# Best path sim 0.43 --> 0.74 --> 0.81 --> 1.00
# Average path sim =  0.43 --> 0.50 --> 0.50 --> 0.46
# Order of best sim  = 1/1 --> 1/10 --> 3/99 --> 1/984
#
# Source target idx = 272
# Best path sim 0.45 --> 0.54 --> 0.53 --> 0.63
# Average path sim =  0.45 --> 0.46 --> 0.45 --> 0.43
# Order of best sim  = 1/1 --> 1/10 --> 4/100 --> 1/815
#
# Source target idx = 273
# Best path sim 0.46 --> 0.50 --> 0.65 --> 0.69
# Average path sim =  0.46 --> 0.49 --> 0.50 --> 0.45
# Order of best sim  = 1/1 --> 4/10 --> 3/100 --> 1/874
#
# Source target idx = 274
# Best path sim 0.29 --> 0.62 --> 1.00
# Average path sim =  0.29 --> 0.34 --> 0.35
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 275
# Best path sim 0.64 --> 0.69 --> 0.88
# Average path sim =  0.64 --> 0.62 --> 0.60
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 276
# Best path sim 0.25 --> 0.49 --> 0.49 --> 0.60
# Average path sim =  0.25 --> 0.41 --> 0.40 --> 0.37
# Order of best sim  = 1/1 --> 1/10 --> 7/73 --> 1/545
#
# Source target idx = 277
# Best path sim 0.49 --> 0.79 --> 1.00
# Average path sim =  0.49 --> 0.57 --> 0.55
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 278
# Best path sim 0.41 --> 0.69 --> 1.00
# Average path sim =  0.41 --> 0.52 --> 0.58
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 279
# Best path sim 0.57 --> 0.74 --> 0.78 --> 0.80
# Average path sim =  0.57 --> 0.61 --> 0.58 --> 0.54
# Order of best sim  = 1/1 --> 1/10 --> 2/91 --> 1/754
#
# Source target idx = 280
# Best path sim 0.36 --> 0.58 --> 0.50 --> 0.66
# Average path sim =  0.36 --> 0.47 --> 0.45 --> 0.40
# Order of best sim  = 1/1 --> 1/10 --> 19/100 --> 1/997
#
# Source target idx = 281
# Best path sim 0.58 --> 0.80
# Average path sim =  0.58 --> 0.64
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 282
# Best path sim 0.38 --> 0.75 --> 0.80 --> 1.00
# Average path sim =  0.38 --> 0.51 --> 0.48 --> 0.44
# Order of best sim  = 1/1 --> 1/10 --> 4/100 --> 1/1000
#
# Source target idx = 283
# Best path sim 0.31 --> 0.71 --> 1.00 --> 1.00
# Average path sim =  0.31 --> 0.38 --> 0.42 --> 0.40
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/726
#
# Source target idx = 284
# Best path sim 0.40 --> 0.46 --> 0.33 --> 0.46
# Average path sim =  0.40 --> 0.39 --> 0.30 --> 0.27
# Order of best sim  = 1/1 --> 1/10 --> 33/100 --> 1/788
#
# Source target idx = 285
# Best path sim 0.21 --> 0.47 --> 0.94
# Average path sim =  0.21 --> 0.32 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 286
# Best path sim 0.40 --> 0.70 --> 1.00
# Average path sim =  0.40 --> 0.43 --> 0.40
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 287
# Best path sim 0.39 --> 0.74 --> 1.00
# Average path sim =  0.39 --> 0.48 --> 0.44
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 288
# Best path sim 0.18 --> 0.45 --> 1.00
# Average path sim =  0.18 --> 0.35 --> 0.47
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 289
# Best path sim 0.40 --> 0.61 --> 0.67
# Average path sim =  0.40 --> 0.54 --> 0.39
# Order of best sim  = 1/1 --> 3/10 --> 1/100
#
# Source target idx = 290
# Best path sim 0.36 --> 0.58 --> 0.92
# Average path sim =  0.36 --> 0.43 --> 0.46
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 291
# Best path sim 0.50 --> 0.82 --> 1.00
# Average path sim =  0.50 --> 0.53 --> 0.50
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 292
# Best path sim 0.33 --> 0.70 --> 1.00
# Average path sim =  0.33 --> 0.43 --> 0.48
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 293
# Best path sim 0.40 --> 0.48 --> 0.68
# Average path sim =  0.40 --> 0.38 --> 0.35
# Order of best sim  = 1/1 --> 3/10 --> 1/100
#
# Source target idx = 294
# Best path sim 0.44 --> 0.44 --> 0.56 --> 0.57
# Average path sim =  0.44 --> 0.43 --> 0.42 --> 0.40
# Order of best sim  = 1/1 --> 4/10 --> 1/100 --> 1/917
#
# Source target idx = 295
# Best path sim 0.39 --> 0.63 --> 0.82
# Average path sim =  0.39 --> 0.48 --> 0.51
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 296
# Best path sim 0.23 --> 0.75 --> 1.00
# Average path sim =  0.23 --> 0.43 --> 0.36
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 297
# Best path sim 0.43 --> 0.62 --> 1.00
# Average path sim =  0.43 --> 0.49 --> 0.48
# Order of best sim  = 1/1 --> 1/10 --> 1/67
#
# Source target idx = 298
# Best path sim 0.25 --> 0.60 --> 1.00
# Average path sim =  0.25 --> 0.34 --> 0.34
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 299
# Best path sim 0.56 --> 0.81
# Average path sim =  0.56 --> 0.64
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 300
# Best path sim 0.28 --> 0.55 --> 1.00
# Average path sim =  0.28 --> 0.36 --> 0.40
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 301
# Best path sim 0.61 --> 0.73 --> 0.88
# Average path sim =  0.61 --> 0.59 --> 0.52
# Order of best sim  = 1/1 --> 1/10 --> 1/48
#
# Source target idx = 302
# Best path sim 0.16 --> 0.63 --> 1.00
# Average path sim =  0.16 --> 0.35 --> 0.45
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 303
# Best path sim 0.17 --> 0.60 --> 1.00
# Average path sim =  0.17 --> 0.40 --> 0.40
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 304
# Best path sim 0.43 --> 0.71 --> 0.89
# Average path sim =  0.43 --> 0.56 --> 0.48
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 305
# Best path sim 0.26 --> 0.59 --> 1.00
# Average path sim =  0.26 --> 0.32 --> 0.31
# Order of best sim  = 1/1 --> 1/10 --> 1/58
#
# Source target idx = 306
# Best path sim 0.42 --> 0.79 --> 1.00
# Average path sim =  0.42 --> 0.47 --> 0.48
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 307
# Best path sim 0.38 --> 0.40 --> 0.57 --> 0.62
# Average path sim =  0.38 --> 0.37 --> 0.36 --> 0.33
# Order of best sim  = 1/1 --> 2/10 --> 3/100 --> 1/629
#
# Source target idx = 308
# Best path sim 0.48 --> 0.55 --> 0.68
# Average path sim =  0.48 --> 0.52 --> 0.45
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 309
# Best path sim 0.50 --> 0.47 --> 0.49 --> 0.64
# Average path sim =  0.50 --> 0.41 --> 0.40 --> 0.38
# Order of best sim  = 1/1 --> 1/10 --> 10/72 --> 1/558
#
# Source target idx = 310
# Best path sim 0.66 --> 0.70 --> 0.70 --> 0.75
# Average path sim =  0.66 --> 0.62 --> 0.62 --> 0.58
# ...
#
# Source target idx = 1826
# Best path sim 0.32 --> 0.65 --> 1.00
# Average path sim =  0.32 --> 0.45 --> 0.35
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1827
# Best path sim 0.28 --> 0.39 --> 0.38 --> 0.51
# Average path sim =  0.28 --> 0.31 --> 0.30 --> 0.27
# Order of best sim  = 1/1 --> 1/10 --> 15/100 --> 1/1000
#
# Source target idx = 1828
# Best path sim 0.22 --> 0.72 --> 1.00
# Average path sim =  0.22 --> 0.31 --> 0.32
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1829
# Best path sim 0.53 --> 0.74 --> 1.00
# Average path sim =  0.53 --> 0.53 --> 0.47
# Order of best sim  = 1/1 --> 1/10 --> 1/99
#
# Source target idx = 1830
# Best path sim 0.13 --> 0.33 --> 0.59 --> 0.70
# Average path sim =  0.13 --> 0.27 --> 0.37 --> 0.36
# Order of best sim  = 1/1 --> 2/10 --> 2/100 --> 1/1000
#
# Source target idx = 1831
# Best path sim 0.25 --> 0.49 --> 0.69 --> 0.71
# Average path sim =  0.25 --> 0.40 --> 0.41 --> 0.35
# Order of best sim  = 1/1 --> 1/10 --> 2/100 --> 1/1000
#
# Source target idx = 1832
# Best path sim 0.32 --> 0.63 --> 0.74 --> 0.82
# Average path sim =  0.32 --> 0.56 --> 0.48 --> 0.41
# Order of best sim  = 1/1 --> 2/10 --> 1/100 --> 1/1000
#
# Source target idx = 1833
# Best path sim 0.27 --> 0.35 --> 0.45 --> 0.54
# Average path sim =  0.27 --> 0.30 --> 0.37 --> 0.36
# Order of best sim  = 1/1 --> 1/10 --> 5/100 --> 1/856
#
# Source target idx = 1834
# Best path sim 0.25 --> 0.33 --> 0.60
# Average path sim =  0.25 --> 0.33 --> 0.36
# Order of best sim  = 1/1 --> 5/10 --> 1/100
#
# Source target idx = 1835
# Best path sim 0.30 --> 0.44 --> 0.72
# Average path sim =  0.30 --> 0.44 --> 0.43
# Order of best sim  = 1/1 --> 5/10 --> 1/100
#
# Source target idx = 1836
# Best path sim 0.26 --> 0.46 --> 0.59 --> 0.74
# Average path sim =  0.26 --> 0.37 --> 0.39 --> 0.38
# Order of best sim  = 1/1 --> 1/10 --> 6/100 --> 1/980
#
# Source target idx = 1837
# Best path sim 0.49 --> 0.87
# Average path sim =  0.49 --> 0.60
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 1838
# Best path sim 0.23 --> 0.59 --> 0.78
# Average path sim =  0.23 --> 0.35 --> 0.34
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1839
# Best path sim 0.47 --> 0.67 --> 0.86
# Average path sim =  0.47 --> 0.59 --> 0.58
# Order of best sim  = 1/1 --> 1/10 --> 1/53
#
# Source target idx = 1840
# Best path sim 0.40 --> 0.78
# Average path sim =  0.40 --> 0.56
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 1841
# Best path sim 0.56 --> 0.86 --> 1.00
# Average path sim =  0.56 --> 0.73 --> 0.65
# Order of best sim  = 1/1 --> 1/10 --> 1/94
#
# Source target idx = 1842
# Best path sim 0.28 --> 0.74 --> 1.00
# Average path sim =  0.28 --> 0.38 --> 0.32
# Order of best sim  = 1/1 --> 1/10 --> 1/55
#
# Source target idx = 1843
# Best path sim 0.56 --> 0.79 --> 0.83 --> 1.00
# Average path sim =  0.56 --> 0.69 --> 0.63 --> 0.54
# Order of best sim  = 1/1 --> 2/10 --> 1/100 --> 1/1000
#
# Source target idx = 1844
# Best path sim 0.57 --> 0.62 --> 1.00
# Average path sim =  0.57 --> 0.56 --> 0.55
# Order of best sim  = 1/1 --> 2/10 --> 1/69
#
# Source target idx = 1845
# Best path sim 0.49 --> 0.55 --> 0.60 --> 0.64
# Average path sim =  0.49 --> 0.51 --> 0.49 --> 0.49
# Order of best sim  = 1/1 --> 3/10 --> 3/100 --> 1/699
#
# Source target idx = 1846
# Best path sim 0.30 --> 0.77 --> 1.00
# Average path sim =  0.30 --> 0.50 --> 0.44
# Order of best sim  = 1/1 --> 1/10 --> 1/83
#
# Source target idx = 1847
# Best path sim 0.29 --> 0.55 --> 0.69
# Average path sim =  0.29 --> 0.45 --> 0.42
# Order of best sim  = 1/1 --> 2/10 --> 1/93
#
# Source target idx = 1848
# Best path sim 0.73 --> 0.80
# Average path sim =  0.73 --> 0.66
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 1849
# Best path sim 0.51 --> 0.86
# Average path sim =  0.51 --> 0.60
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 1850
# Best path sim 0.63 --> 0.64
# Average path sim =  0.63 --> 0.52
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 1851
# Best path sim 0.36 --> 0.60 --> 0.62
# Average path sim =  0.36 --> 0.35 --> 0.31
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1852
# Best path sim 0.25 --> 0.66 --> 1.00 --> 1.00
# Average path sim =  0.25 --> 0.51 --> 0.40 --> 0.32
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/921
#
# Source target idx = 1853
# Best path sim 0.43 --> 0.63 --> 1.00
# Average path sim =  0.43 --> 0.54 --> 0.52
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1854
# Best path sim 0.41 --> 0.64 --> 1.00
# Average path sim =  0.41 --> 0.43 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1855
# Best path sim 0.30 --> 0.54 --> 0.73 --> 0.75
# Average path sim =  0.30 --> 0.43 --> 0.42 --> 0.35
# Order of best sim  = 1/1 --> 2/10 --> 1/100 --> 1/990
#
# Source target idx = 1856
# Best path sim 0.28 --> 0.43 --> 0.73
# Average path sim =  0.28 --> 0.38 --> 0.38
# Order of best sim  = 1/1 --> 3/10 --> 1/100
#
# Source target idx = 1857
# Best path sim 0.27 --> 0.33 --> 0.51
# Average path sim =  0.27 --> 0.30 --> 0.30
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 1858
# Best path sim 0.15 --> 0.63 --> 1.00
# Average path sim =  0.15 --> 0.32 --> 0.34
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1859
# Best path sim 0.54 --> 0.65 --> 0.62 --> 0.67
# Average path sim =  0.54 --> 0.54 --> 0.52 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 3/37 --> 1/206
#
# Source target idx = 1860
# Best path sim 0.36 --> 0.41 --> 0.70
# Average path sim =  0.36 --> 0.38 --> 0.40
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 1861
# Best path sim 0.38 --> 0.51 --> 0.72 --> 0.75
# Average path sim =  0.38 --> 0.46 --> 0.45 --> 0.42
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/856
#
# Source target idx = 1862
# Best path sim 0.52 --> 0.86 --> 0.71 --> 0.86
# Average path sim =  0.52 --> 0.54 --> 0.50 --> 0.44
# Order of best sim  = 1/1 --> 1/10 --> 3/100 --> 1/925
#
# Source target idx = 1863
# Best path sim 0.37 --> 0.51 --> 0.49 --> 0.55
# Average path sim =  0.37 --> 0.42 --> 0.42 --> 0.40
# Order of best sim  = 1/1 --> 1/10 --> 11/100 --> 1/1000
#
# Source target idx = 1864
# Best path sim 0.52 --> 0.71 --> 0.71 --> 1.00
# Average path sim =  0.52 --> 0.53 --> 0.51 --> 0.47
# Order of best sim  = 1/1 --> 1/10 --> 9/100 --> 1/1000
#
# Source target idx = 1865
# Best path sim 0.41 --> 0.42 --> 0.62
# Average path sim =  0.41 --> 0.40 --> 0.40
# Order of best sim  = 1/1 --> 4/10 --> 1/100
#
# Source target idx = 1866
# Best path sim 0.52 --> 0.52 --> 0.46 --> 0.68
# Average path sim =  0.52 --> 0.48 --> 0.41 --> 0.36
# Order of best sim  = 1/1 --> 1/10 --> 18/100 --> 1/1000
#
# Source target idx = 1867
# Best path sim 0.43 --> 0.58 --> 0.82 --> 1.00
# Average path sim =  0.43 --> 0.42 --> 0.38 --> 0.34
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/977
#
# Source target idx = 1868
# Best path sim 0.28 --> 0.85
# Average path sim =  0.28 --> 0.38
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 1869
# Best path sim 0.35 --> 0.66 --> 1.00
# Average path sim =  0.35 --> 0.47 --> 0.46
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1870
# Best path sim 0.65 --> 0.62 --> 0.74
# Average path sim =  0.65 --> 0.61 --> 0.57
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 1871
# Best path sim 0.39 --> 0.54 --> 0.61
# Average path sim =  0.39 --> 0.45 --> 0.37
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1872
# Best path sim 0.42 --> 0.65
# Average path sim =  0.42 --> 0.51
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 1873
# Best path sim 0.59 --> 0.63 --> 0.76
# Average path sim =  0.59 --> 0.61 --> 0.60
# Order of best sim  = 1/1 --> 5/10 --> 1/100
#
# Source target idx = 1874
# Best path sim 0.45 --> 0.75 --> 1.00
# Average path sim =  0.45 --> 0.45 --> 0.39
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1875
# Best path sim 0.52 --> 0.56 --> 0.56 --> 0.69
# Average path sim =  0.52 --> 0.52 --> 0.49 --> 0.46
# Order of best sim  = 1/1 --> 1/10 --> 7/100 --> 1/1000
#
# Source target idx = 1876
# Best path sim 0.32 --> 0.32 --> 0.33 --> 0.54
# Average path sim =  0.32 --> 0.29 --> 0.30 --> 0.26
# Order of best sim  = 1/1 --> 2/10 --> 27/100 --> 1/1000
#
# Source target idx = 1877
# Best path sim 0.21 --> 0.70 --> 1.00
# Average path sim =  0.21 --> 0.37 --> 0.39
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1878
# Best path sim 0.52 --> 0.69 --> 0.72 --> 0.74
# Average path sim =  0.52 --> 0.51 --> 0.48 --> 0.45
# Order of best sim  = 1/1 --> 1/10 --> 1/100 --> 1/809
#
# Source target idx = 1879
# Best path sim 0.19 --> 0.33 --> 0.58
# Average path sim =  0.19 --> 0.23 --> 0.27
# Order of best sim  = 1/1 --> 2/10 --> 1/90
#
# Source target idx = 1880
# Best path sim 0.60 --> 0.70 --> 0.84
# Average path sim =  0.60 --> 0.59 --> 0.58
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1881
# Best path sim 0.14 --> 0.58 --> 0.80 --> 0.80
# Average path sim =  0.14 --> 0.28 --> 0.28 --> 0.25
# Order of best sim  = 1/1 --> 1/10 --> 1/99 --> 1/857
#
# Source target idx = 1882
# Best path sim 0.47 --> 0.70 --> 1.00
# Average path sim =  0.47 --> 0.52 --> 0.51
# Order of best sim  = 1/1 --> 1/10 --> 1/41
#
# Source target idx = 1883
# Best path sim 0.34 --> 0.41 --> 0.67
# Average path sim =  0.34 --> 0.39 --> 0.41
# Order of best sim  = 1/1 --> 4/10 --> 1/100
#
# Source target idx = 1884
# Best path sim 0.49 --> 0.56 --> 0.49 --> 0.56
# Average path sim =  0.49 --> 0.45 --> 0.43 --> 0.38
# Order of best sim  = 1/1 --> 1/10 --> 8/47 --> 1/328
#
# Source target idx = 1885
# Best path sim 0.31 --> 0.83 --> 1.00
# Average path sim =  0.31 --> 0.39 --> 0.41
# Order of best sim  = 1/1 --> 1/10 --> 1/68
#
# Source target idx = 1886
# Best path sim 0.19 --> 0.68 --> 1.00
# Average path sim =  0.19 --> 0.43 --> 0.46
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1887
# Best path sim 0.23 --> 0.40 --> 0.50 --> 0.52
# Average path sim =  0.23 --> 0.32 --> 0.32 --> 0.27
# Order of best sim  = 1/1 --> 1/10 --> 3/100 --> 1/1000
#
# Source target idx = 1888
# Best path sim 0.25 --> 0.76 --> 1.00
# Average path sim =  0.25 --> 0.44 --> 0.44
# Order of best sim  = 1/1 --> 1/10 --> 1/54
#
# Source target idx = 1889
# Best path sim 0.55 --> 0.54 --> 0.66
# Average path sim =  0.55 --> 0.52 --> 0.48
# Order of best sim  = 1/1 --> 4/10 --> 1/100
#
# Source target idx = 1890
# Best path sim 0.24 --> 0.34 --> 0.70
# Average path sim =  0.24 --> 0.35 --> 0.44
# Order of best sim  = 1/1 --> 5/10 --> 1/100
#
# Source target idx = 1891
# Best path sim 0.37 --> 0.80 --> 1.00
# Average path sim =  0.37 --> 0.41 --> 0.40
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1892
# Best path sim 0.45 --> 0.62 --> 1.00
# Average path sim =  0.45 --> 0.48 --> 0.50
# Order of best sim  = 1/1 --> 1/10 --> 1/54
#
# Source target idx = 1893
# Best path sim 0.57 --> 0.76 --> 0.91 --> 1.00
# Average path sim =  0.57 --> 0.69 --> 0.67 --> 0.59
# Order of best sim  = 1/1 --> 1/10 --> 3/100 --> 1/1000
#
# Source target idx = 1894
# Best path sim 0.56 --> 0.62 --> 0.82
# Average path sim =  0.56 --> 0.62 --> 0.60
# Order of best sim  = 1/1 --> 4/10 --> 1/100
#
# Source target idx = 1895
# Best path sim 0.62 --> 0.83 --> 0.86
# Average path sim =  0.62 --> 0.72 --> 0.66
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1896
# Best path sim 0.59 --> 0.86 --> 0.89
# Average path sim =  0.59 --> 0.61 --> 0.52
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1897
# Best path sim 0.57 --> 0.50 --> 0.52 --> 0.69
# Average path sim =  0.57 --> 0.56 --> 0.52 --> 0.46
# Order of best sim  = 1/1 --> 8/10 --> 51/100 --> 1/808
#
# Source target idx = 1898
# Best path sim 0.74 --> 0.80
# Average path sim =  0.74 --> 0.71
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 1899
# Best path sim 0.27 --> 0.81 --> 1.00
# Average path sim =  0.27 --> 0.33 --> 0.31
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1900
# Best path sim 0.45 --> 0.67 --> 1.00
# Average path sim =  0.45 --> 0.59 --> 0.56
# Order of best sim  = 1/1 --> 1/10 --> 1/92
#
# Source target idx = 1901
# Best path sim 0.47 --> 0.69 --> 0.69 --> 0.91
# Average path sim =  0.47 --> 0.58 --> 0.56 --> 0.55
# Order of best sim  = 1/1 --> 1/10 --> 5/100 --> 1/810
#
# Source target idx = 1902
# Best path sim 0.22 --> 0.38 --> 1.00
# Average path sim =  0.22 --> 0.27 --> 0.35
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1903
# Best path sim 0.54 --> 0.54 --> 0.48 --> 0.54
# Average path sim =  0.54 --> 0.44 --> 0.37 --> 0.33
# Order of best sim  = 1/1 --> 1/10 --> 3/100 --> 1/988
#
# Source target idx = 1904
# Best path sim 0.52 --> 0.70 --> 1.00
# Average path sim =  0.52 --> 0.60 --> 0.55
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1905
# Best path sim 0.45 --> 0.31 --> 0.39 --> 0.49
# Average path sim =  0.45 --> 0.34 --> 0.30 --> 0.22
# Order of best sim  = 1/1 --> 8/10 --> 7/100 --> 1/1000
#
# Source target idx = 1906
# Best path sim 0.55 --> 0.89 --> 1.00
# Average path sim =  0.55 --> 0.79 --> 0.77
# Order of best sim  = 1/1 --> 2/10 --> 1/100
#
# Source target idx = 1907
# Best path sim 0.14 --> 0.36 --> 0.76 --> 1.00
# Average path sim =  0.14 --> 0.32 --> 0.36 --> 0.33
# Order of best sim  = 1/1 --> 3/10 --> 1/100 --> 1/1000
#
# Source target idx = 1908
# Best path sim 0.44 --> 0.61 --> 0.83
# Average path sim =  0.44 --> 0.51 --> 0.54
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1909
# Best path sim 0.49 --> 0.61 --> 0.62 --> 0.71
# Average path sim =  0.49 --> 0.57 --> 0.53 --> 0.49
# Order of best sim  = 1/1 --> 1/10 --> 16/100 --> 1/1000
#
# Source target idx = 1910
# Best path sim 0.56 --> 0.59 --> 0.63 --> 0.78
# Average path sim =  0.56 --> 0.57 --> 0.48 --> 0.46
# Order of best sim  = 1/1 --> 3/10 --> 1/100 --> 1/833
#
# Source target idx = 1911
# Best path sim 0.46 --> 0.76 --> 1.00
# Average path sim =  0.46 --> 0.44 --> 0.36
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1912
# Best path sim 0.32 --> 0.42
# Average path sim =  0.32 --> 0.35
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 1913
# Best path sim 0.31 --> 0.62
# Average path sim =  0.31 --> 0.45
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 1914
# Best path sim 0.60 --> 0.86 --> 1.00
# Average path sim =  0.60 --> 0.61 --> 0.54
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1915
# Best path sim 0.49 --> 0.81 --> 1.00
# Average path sim =  0.49 --> 0.69 --> 0.69
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1916
# Best path sim 0.27 --> 0.22 --> 0.19 --> 0.41
# Average path sim =  0.27 --> 0.25 --> 0.22 --> 0.21
# Order of best sim  = 1/1 --> 8/10 --> 76/100 --> 1/1000
#
# Source target idx = 1917
# Best path sim 0.22 --> 0.40
# Average path sim =  0.22 --> 0.31
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 1918
# Best path sim 0.30 --> 0.43 --> 0.38 --> 0.53
# Average path sim =  0.30 --> 0.37 --> 0.36 --> 0.31
# Order of best sim  = 1/1 --> 2/10 --> 40/100 --> 1/1000
#
# Source target idx = 1919
# Best path sim 0.32 --> 0.79 --> 0.79 --> 1.00
# Average path sim =  0.32 --> 0.46 --> 0.45 --> 0.44
# Order of best sim  = 1/1 --> 1/10 --> 10/100 --> 1/901
#
# Source target idx = 1920
# Best path sim 0.56 --> 0.62 --> 0.64
# Average path sim =  0.56 --> 0.56 --> 0.52
# Order of best sim  = 1/1 --> 3/10 --> 1/100
#
# Source target idx = 1921
# Best path sim 0.22 --> 0.27 --> 0.74 --> 1.00
# Average path sim =  0.22 --> 0.30 --> 0.35 --> 0.32
# Order of best sim  = 1/1 --> 3/10 --> 2/100 --> 1/881
#
# Source target idx = 1922
# Best path sim 0.27 --> 0.37 --> 0.45 --> 0.61
# Average path sim =  0.27 --> 0.36 --> 0.34 --> 0.31
# Order of best sim  = 1/1 --> 4/10 --> 7/76 --> 1/569
#
# Source target idx = 1923
# Best path sim 0.66 --> 0.73 --> 1.00
# Average path sim =  0.66 --> 0.59 --> 0.54
# Order of best sim  = 1/1 --> 1/10 --> 1/100
#
# Source target idx = 1924
# Best path sim 0.41 --> 0.59
# Average path sim =  0.41 --> 0.50
# Order of best sim  = 1/1 --> 1/10
#
# Source target idx = 1925
# Best path sim 0.38 --> 0.56 --> 0.82
# Average path sim =  0.38 --> 0.55 --> 0.59
# Order of best sim  = 1/1 --> 5/10 --> 1/100
#
# Source target idx = 1926
# Best path sim 0.15 --> 0.27 --> 0.56
# Average path sim =  0.15 --> 0.29 --> 0.35
# Order of best sim  = 1/1 --> 5/10 --> 1/100
#
# Source target idx = 1927
# Best path sim 0.37 --> 0.72 --> 0.72
# Average path sim =  0.37 --> 0.51 --> 0.47
# Order of best sim  = 1/1 --> 1/10 --> 1/100
